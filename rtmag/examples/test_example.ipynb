# %%
from rtmag.process.download.find_harp import find_ar

# %%
d = "2024-05-09 02:00:00"
ar, img = find_ar(d, show_image=True)
print(ar)
# Out:
#     NOAA_AR  HARPNUM
# 0     13663    11142
# 1     13664    11149
# 2         0    11150
# 3     13666    11152
# 4     13665    11159
# 5     13667    11170
# 6         0    11173
# 7     13670    11178
# 8         0    11182
# 9         0    11186
# 10        0    11187
# 11        0    11189
# 12    13672    11190
# 13    13679    11192
# 14        0    11194
# 15        0    11195

# %%
from IPython.display import Image

# %%
Image(img)

# %%
harpnum = 11149
noaanum = ar[ar['HARPNUM'] == harpnum]['NOAA_AR'].item()
print(noaanum)
# Out:
# 13664

# %%
from rtmag.process.download.dl_map import get_sharp_map

# %%
hmi_map, hmi_data = get_sharp_map(d, harpnum)
# Out:
# T_REC:  2024.05.09_02:00:00_TAI
# http://jsoc.stanford.edu/SUM93/D1753918816/S00000/Bp.fits

# %%
hmi_map.peek()

# %%
hmi_data.shape
# Out:
# (1202, 513, 3)

# %%
from rtmag.process.paper.hmi_to_input import get_input

# %%
nx = 512
ny = 256

model_input, x, y, z, dx, dy, dz = get_input(hmi_data, nx, ny)
model_input.shape
print(model_input.max())
# Out:
# dx = 0.8565051313650011 Mm
# dy = 0.7317077289490391 Mm
# dz = 0.7317077289490391 Mm
# 2854.0552

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
meta_path = "/cidashome/sc/c0315yokota/template_pytorch/rtmag/D:/models/lowlou_high_div/model_19.pt"
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import torch
#       2 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#       3 meta_path = "/cidashome/sc/c0315yokota/template_pytorch/rtmag/D:/models/lowlou_high_div/model_19.pt"
#
# File ~/template_pytorch/.venv/lib/python3.12/site-packages/torch/__init__.py:2169
#    2153 ################################################################################
#    2154 # Import most common subpackages
#    2155 ################################################################################
#    (...)   2160
#    2161 # needs to be before import torch.nn as nn to avoid circular dependencies
#    2162 from torch.autograd import (  # usort: skip
#    2163     enable_grad as enable_grad,
#    2164     inference_mode as inference_mode,
#    2165     no_grad as no_grad,
#    2166     set_grad_enabled as set_grad_enabled,
#    2167 )
# -> 2169 from torch import (
#    2170     __config__ as __config__,
#    2171     __future__ as __future__,
#    2172     _awaits as _awaits,
#    2173     accelerator as accelerator,
#    2174     autograd as autograd,
#    2175     backends as backends,
#    2176     cpu as cpu,
#    2177     cuda as cuda,
#    2178     distributed as distributed,
#    2179     distributions as distributions,
#    2180     fft as fft,
#    2181     futures as futures,
#    2182     hub as hub,
#    2183     jit as jit,
#    2184     linalg as linalg,
#    2185     mps as mps,
#    2186     mtia as mtia,
#    2187     multiprocessing as multiprocessing,
#    2188     nested as nested,
#    2189     nn as nn,
#    2190     optim as optim,
#    2191     overrides as overrides,
#    2192     profiler as profiler,
#    2193     sparse as sparse,
#    2194     special as special,
#    2195     testing as testing,
#    2196     types as types,
#    2197     utils as utils,
#    2198     xpu as xpu,
#    2199 )
#    2200 from torch.signal import windows as windows
#    2203 # Quantized, sparse, AO, etc. should be last to get imported, as nothing
#    2204 # is expected to depend on them.
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:991, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1087, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1186, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
from rtmag.process.paper.load import MyModel

mm = MyModel(meta_path, device=device)
# Out:
# Model loaded from epoch 19

# %%
b = mm.get_pred_from_numpy(model_input)
b.shape
print(b.max())
# Out:
# b_norm = 200 G
# cuda:0
# 2.9428822994232178 seconds
# nan

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
bottom = b[:, :, 0, 2]
print(bottom.max())
# Out:
# nan

# %%
fig, ax = plt.subplots()
ax.pcolormesh(x, y, bottom.T, cmap='gray', vmin=-2000, vmax=2000)
ax.set_xlabel('x [Mm]')
ax.set_ylabel('y [Mm]')
ax.set_aspect('equal')
ax.set_title("PINO's output at z=0")
plt.tight_layout()
plt.show()

# %%
mask = np.abs(bottom) > 1000
fig, ax = plt.subplots()
ax.pcolormesh(x, y, (bottom*mask).T, cmap='gray', vmin=-2000, vmax=2000)
ax.set_xlabel('x [Mm]')
ax.set_ylabel('y [Mm]')
ax.set_aspect('equal')
plt.tight_layout()
plt.show()

# %%
stride = 20
seeds = np.stack([np.where(mask == True)[0], 
                  np.where(mask == True)[1], 
                  np.zeros_like(np.where(mask == True)[0])], axis=1)
seeds = seeds[::stride]
seeds.shape
# Out:
# (0, 3)

# %%
from streamtracer import StreamTracer, VectorGrid

# %%
nsteps = 10000
step_size = 0.1
grid_spacing = [1, 1, 1]

grid = VectorGrid(b.astype(np.float64), grid_spacing)
tracer = StreamTracer(nsteps, step_size)
tracer_xs = []
tracer.trace(seeds, grid)
tracer_xs.append(tracer.xs)
tracer_xs = [item for sublist in tracer_xs for item in sublist]
# Out:
# thread '<unnamed>' panicked at src/trace.rs:77:53:
# called `Result::unwrap()` on an `Err` value: ShapeError/Unsupported: unsupported operation
# note: run with `RUST_BACKTRACE=1` environment variable to display a backtrace
# ---------------------------------------------------------------------------
# PanicException                            Traceback (most recent call last)
# Cell In[21], line 8
#       6 tracer = StreamTracer(nsteps, step_size)
#       7 tracer_xs = []
# ----> 8 tracer.trace(seeds, grid)
#       9 tracer_xs.append(tracer.xs)
#      10 tracer_xs = [item for sublist in tracer_xs for item in sublist]
#
# File ~/template_pytorch/.venv/lib/python3.12/site-packages/streamtracer/streamline.py:329, in StreamTracer.trace(self, seeds, grid, direction)
#     325     self.xs = [xi[:ni, :] for xi, ni in zip(self.xs, self.ns)]
#     327 elif direction == 0:
#     328     # Calculate forward streamline
# --> 329     xs_f, ns_f, ROT_f = trace_streamlines(
#     330         seeds,
#     331         xcoords,
#     332         ycoords,
#     333         zcoords,
#     334         field,
#     335         cyclic,
#     336         1,
#     337         self.ds,
#     338         self.max_steps,
#     339     )
#     340     # Calculate backward streamline
#     341     xs_r, ns_r, ROT_r = trace_streamlines(
#     342         seeds,
#     343         xcoords,
#    (...)    350         self.max_steps,
#     351     )
#
# PanicException: called `Result::unwrap()` on an `Err` value: ShapeError/Unsupported: unsupported operation

# %%
fig, ax = plt.subplots()
ax.pcolormesh(x, y, bottom.T, cmap='gray', vmin=-2000, vmax=2000)
ax.set_xlabel('x [Mm]')
ax.set_ylabel('y [Mm]')
ax.set_aspect('equal')
for i, xl in enumerate(tracer_xs):
    assert seeds[i] in xl 
    ax.plot(xl[:,0]*dx+x[0], xl[:,1]*dy+y[0], color='blue', linewidth=0.8)
plt.tight_layout()
plt.show()

# %%
import pyvista as pv

# %%
xv, yv, zv = np.meshgrid(x, y, z, indexing='ij')
mesh = pv.StructuredGrid(xv, yv, zv)
bx, by, bz = b[..., 0], b[..., 1], b[..., 2]
vectors = np.stack([bx, by, bz], axis=-1).transpose(2, 1, 0, 3).reshape(-1, 3)
mesh['vector'] = vectors
mesh.active_vectors_name = 'vector'
mesh
# Out:
# StructuredGrid (0x756a393e6e00)
#   N Cells:      33227775
#   N Points:     33554432
#   X Bounds:     0.000e+00, 4.377e+02
#   Y Bounds:     0.000e+00, 1.866e+02
#   Z Bounds:     0.000e+00, 1.866e+02
#   Dimensions:   512, 256, 256
#   N Arrays:     1

# %%
xx, yy = np.meshgrid(x, y, indexing='ij')
seeds_xs = np.stack([xx[seeds[:, 0], seeds[:, 1]], 
                     yy[seeds[:, 0], seeds[:, 1]], 
                     np.zeros_like(seeds[:, 0])], axis=1)
seeds_xs.shape
# Out:
# (231, 3)

# %%
pv.global_theme.notebook = True
pv.global_theme.jupyter_backend = 'static'
# pv.global_theme.jupyter_backend = 'trame'

# %%
p = pv.Plotter(window_size=(1000, 600))

p.show_bounds(
    grid='front',
    show_xlabels=False,
    show_ylabels=False,
    show_zlabels=False,
)
p.add_mesh(mesh.outline(), color='k')

seed = pv.PolyData(seeds_xs)
strl = mesh.streamlines_from_source(seed, vectors='vector', integration_direction='both',
                                    max_time=10000, initial_step_length=0.1)
p.add_mesh(strl.tube(radius=0.4), color='blue')

bottom_subset = mesh.extract_subset((0, nx-1, 0, ny-1, 0, 0)).extract_surface()
p.add_mesh(bottom_subset, cmap='gray', scalars='vector', component=2, clim=(-2000, 2000), 
           lighting=False, show_scalar_bar=False)

p.camera_position = "xy"
p.camera.roll = -30
p.camera.elevation = -70
p.camera.zoom(1.3)
p.show()
# Out:
# 2025-07-28 23:36:23.962 (  24.426s) [    756E4DDC5080]vtkXOpenGLRenderWindow.:1416  WARN| bad X server connection. DISPLAY=
# /cidashome/sc/c0315yokota/template_pytorch/.venv/lib/python3.12/site-packages/pyvista/core/filters/data_set.py:3066: PyVistaDeprecationWarning: ``max_time`` parameter is deprecated.  It will be removed in v0.48
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1000x600>

# %%
from rtmag.process.download.dl_map import get_aia_map

# %%
import warnings; warnings.filterwarnings('ignore')

# %%
aia94_map = get_aia_map(d, wavelength=94)
aia131_map = get_aia_map(d, wavelength=131)
aia171_map = get_aia_map(d, wavelength=171)
aia193_map = get_aia_map(d, wavelength=193)
aia211_map = get_aia_map(d, wavelength=211)
aia304_map = get_aia_map(d, wavelength=304)
aia335_map = get_aia_map(d, wavelength=335)
# Out:
# T_REC:  2024-05-09T01:59:59Z
# T_REC:  2024-05-09T01:59:59Z
# T_REC:  2024-05-09T01:59:59Z
# T_REC:  2024-05-09T01:59:59Z
# T_REC:  2024-05-09T01:59:59Z
# T_REC:  2024-05-09T01:59:59Z
# T_REC:  2024-05-09T01:59:59Z

# %%
import astropy.units as u

# %%
aia94_map_repro = aia94_map.reproject_to(hmi_map.wcs)
aia94_map_repro = aia94_map_repro.resample([nx, ny] * u.pixel)

aia131_map_repro = aia131_map.reproject_to(hmi_map.wcs)
aia131_map_repro = aia131_map_repro.resample([nx, ny] * u.pixel)

aia171_map_repro = aia171_map.reproject_to(hmi_map.wcs)
aia171_map_repro = aia171_map_repro.resample([nx, ny] * u.pixel)

aia193_map_repro = aia193_map.reproject_to(hmi_map.wcs)
aia193_map_repro = aia193_map_repro.resample([nx, ny] * u.pixel)

aia211_map_repro = aia211_map.reproject_to(hmi_map.wcs)
aia211_map_repro = aia211_map_repro.resample([nx, ny] * u.pixel)

aia304_map_repro = aia304_map.reproject_to(hmi_map.wcs)
aia304_map_repro = aia304_map_repro.resample([nx, ny] * u.pixel)

aia335_map_repro = aia335_map.reproject_to(hmi_map.wcs)
aia335_map_repro = aia335_map_repro.resample([nx, ny] * u.pixel)
# Out:
# 2025-07-28 23:36:40 - reproject.common - INFO: Calling _reproject_full in non-dask mode
# 2025-07-28 23:36:41 - reproject.common - INFO: Calling _reproject_full in non-dask mode
# 2025-07-28 23:36:41 - reproject.common - INFO: Calling _reproject_full in non-dask mode
# 2025-07-28 23:36:42 - reproject.common - INFO: Calling _reproject_full in non-dask mode
# 2025-07-28 23:36:43 - reproject.common - INFO: Calling _reproject_full in non-dask mode
# 2025-07-28 23:36:43 - reproject.common - INFO: Calling _reproject_full in non-dask mode
# 2025-07-28 23:36:44 - reproject.common - INFO: Calling _reproject_full in non-dask mode

# %%
aia171_map_repro.peek()

# %%
from rtmag.process.paper.utils import get_j_map_Mm

# %%
j_map, jz_btm = get_j_map_Mm(b, dx, dy, dz)

# %%
plt.rcParams['font.size'] = 12
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(10, 13), sharex=True, sharey=True)
axes = axes.flatten()

ax = axes[0]
ax.pcolormesh(x, y, bottom.T, cmap='gray', vmin=-2000, vmax=2000)
# ax.set_xlabel('x [Mm]')
ax.set_ylabel('y [Mm]')
ax.set_aspect('equal')
for i, xl in enumerate(tracer_xs):
    assert seeds[i] in xl 
    ax.plot(xl[:,0]*dx+x[0], xl[:,1]*dy+y[0], color='blue', linewidth=0.8)
ax.set_title("PINO magnetic field line")

ax = axes[1]
ax.pcolormesh(x, y, j_map.T, cmap='plasma',  vmin=0, vmax=2000)
# ax.set_xlabel('x [Mm]')
# ax.set_ylabel('y [Mm]')
ax.set_aspect('equal')
ax.set_title("PINO integrated current density map")

ax = axes[2]
ax.pcolormesh(x, y, bottom.T, cmap='gray', vmin=-2000, vmax=2000)
# ax.set_xlabel('x [Mm]')
ax.set_ylabel('y [Mm]')
ax.set_aspect('equal')
ax.set_title("Photospheric magnetic field")

ax = axes[3]
ax.pcolormesh(x, y, aia94_map_repro.data, 
              norm = aia94_map_repro.plot_settings['norm'],
              cmap = aia94_map_repro.plot_settings['cmap'],) 
# ax.set_xlabel('x [Mm]')
# ax.set_ylabel('y [Mm]')
ax.set_aspect('equal')
ax.set_title("AIA 94 $\AA$")

ax = axes[4]
ax.pcolormesh(x, y, aia131_map_repro.data, 
              norm = aia131_map_repro.plot_settings['norm'],
              cmap = aia131_map_repro.plot_settings['cmap'],) 
# ax.set_xlabel('x [Mm]')
ax.set_ylabel('y [Mm]')
ax.set_aspect('equal')
ax.set_title("AIA 131 $\AA$")

ax = axes[5]
ax.pcolormesh(x, y, aia171_map_repro.data, 
              norm = aia171_map_repro.plot_settings['norm'],
              cmap = aia171_map_repro.plot_settings['cmap'],)
# ax.set_xlabel('x [Mm]')
# ax.set_ylabel('y [Mm]')
ax.set_aspect('equal')
ax.set_title("AIA 171 $\AA$")

ax = axes[6]
ax.pcolormesh(x, y, aia193_map_repro.data, 
              norm = aia193_map_repro.plot_settings['norm'],
              cmap = aia193_map_repro.plot_settings['cmap'],)
# ax.set_xlabel('x [Mm]')
ax.set_ylabel('y [Mm]')
ax.set_aspect('equal')
ax.set_title("AIA 193 $\AA$")

ax = axes[7]
ax.pcolormesh(x, y, aia211_map_repro.data, 
              norm = aia211_map_repro.plot_settings['norm'],
              cmap = aia211_map_repro.plot_settings['cmap'],)
# ax.set_xlabel('x [Mm]')
# ax.set_ylabel('y [Mm]')
ax.set_aspect('equal')
ax.set_title("AIA 211 $\AA$")

ax = axes[8]
ax.pcolormesh(x, y, aia304_map_repro.data, 
              norm = aia304_map_repro.plot_settings['norm'],
              cmap = aia304_map_repro.plot_settings['cmap'],)
ax.set_xlabel('x [Mm]')
ax.set_ylabel('y [Mm]')
ax.set_aspect('equal')
ax.set_title("AIA 304 $\AA$")

ax = axes[9]
ax.pcolormesh(x, y, aia335_map_repro.data, 
              norm = aia335_map_repro.plot_settings['norm'],
              cmap = aia335_map_repro.plot_settings['cmap'],)
ax.set_xlabel('x [Mm]')
# ax.set_ylabel('y [Mm]')
ax.set_aspect('equal')
ax.set_title("AIA 335 $\AA$")

fig.suptitle(f"AR {noaanum} at {d}", y=1.01)
plt.tight_layout()
plt.show()

# %%
fl_cmap = plt.get_cmap('rainbow')
fl_norm = plt.Normalize(vmin=0, vmax=30)
values = np.abs(jz_btm.T[seeds[:, 0], seeds[:, 1]])

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10, 6))
ax.pcolormesh(x, y, bottom.T, cmap='gray', vmin=-2000, vmax=2000)
ax.set_xlabel('x [Mm]')
ax.set_ylabel('y [Mm]')
ax.set_aspect('equal')
colors = fl_cmap(fl_norm(values))
for i, xl in enumerate(tracer_xs):
    assert seeds[i] in xl 
    ax.plot(xl[:,0]*dx+x[0], xl[:,1]*dy+y[0], color=colors[i], linewidth=0.8)

plt.tight_layout()
plt.show()
